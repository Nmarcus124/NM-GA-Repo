# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/natimarcus/Desktop/DAT-06-24/class material/Unit 1/data/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts().plot(kind='bar')

# %%
df['Embarked'].head(10)
# Out:
# 0    S
# 1    C
# 2    S
# 3    S
# 4    S
# 5    Q
# 6    S
# 7    S
# 8    S
# 9    C
# Name: Embarked, dtype: object

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby('Sex')['Survived'].mean().plot(kind='bar')

# %%
df.groupby('Sex')['Survived'].mean().plot(kind='barh')

# %%
df.groupby('Sex')[['Age','Fare']].mean().plot(kind='bar')
plt.title('Age and Fare by Gender');

# %%
df['Embarked'].value_counts().plot(kind='pie')

# %%
df['Age'].plot(kind='Hist')

# %%
df['Age'].plot(kind='Hist', bins=20)

# %%
df.hist(column='Age', by='Embarked') #makes histogram for each value in 'Embarked'
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11fe22c88>,
# ...
#       dtype=object)

# %%
df.hist(column='Age', by='Embarked', layout=(1,3)) # (#of rows, #of columns)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11f7e5c88>,
# ...
#       dtype=object)

# %%
df.hist(column='Age', by='Embarked', layout=(1,3), figsize=(12,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x120092ef0>,
# ...
#       dtype=object)

# %%
df.hist(column='Age', by='Embarked', layout=(1,3), figsize=(12,4), sharey=True) #makes all three histograms have the same scale for y-axis
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x12027d390>,
# ...
#       dtype=object)

# %%
df['Age'].plot(kind='kde') #shows probability of each bin/value

# %%
df.plot('Age','Fare',kind='scatter')

# %%
fig, ax = plt.subplots(1,2)

# %%
ax
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a2226c710>,
# ...
#       dtype=object)

# %%
fig, ax = plt.subplots(1,2)
df[df.Sex == 'female'].plot('Age','Fare',kind='Scatter',ax=ax[0],color='red',label='Females')
df[df.Sex == 'male'].plot('Age','Fare',kind='Scatter',ax=ax[1],color='blue',label='Males')

# %%
fig, ax = plt.subplots(1,2, sharex=True, sharey=True, figsize=(12,4))
df[df.Sex == 'female'].plot('Age','Fare',kind='Scatter',ax=ax[0],color='red',label='Females')
df[df.Sex == 'male'].plot('Age','Fare',kind='Scatter',ax=ax[1],color='blue',label='Males')

# %%
fig, ax = plt.subplots(2,2)
ax
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2277e780>,
# ...
#       dtype=object)

# %%
ax[0] #returns first row of subplots
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a2277e780>,
# ...
#       dtype=object)

# %%
ax[0][0] #returns first axis first row

# %%
ax[1][1] #second item second row

# %%
import seaborn as sns

# %%
sns.catplot(x='Pclass', y='Age', data=df)

# %%
sns.catplot(x='Pclass', y='Age', kind='swarm', data=df)

# %%
sns.catplot(x='Pclass', y='Age', kind='box', data=df)

# %%
sns.catplot(x='Pclass', y='Age', kind='boxen', data=df)

# %%
sns.catplot(x='Pclass', y='Age', kind='violin', data=df)

# %%
sns.catplot(x='Pclass', y='Age', kind='point', data=df)

# %%
sns.catplot(x='Pclass', y='Age', kind='bar', data=df)

# %%
sns.catplot(x='Pclass', kind='count', data=df)

# %%
sns.catplot(x='Age', kind='count', data=df)

# %%
sns.catplot(x='Pclass', y='Age', kind='swarm',hue='Sex', data=df)

# %%
sns.catplot(x='Pclass', y='Fare', kind='swarm',col='Sex', data=df)

# %%
sns.catplot(x='Pclass', y='Fare', kind='swarm',row='Sex', data=df)

# %%
sns.catplot(x='Pclass', y='Survived', kind='bar', hue='Sex', data=df);
plt.title('survival rate by passenger class/sex');

# %%
sns.lmplot(x='Pclass', y='Survived', data=df)

# %%
df['Age'] = df['Age'].fillna(29)
sns.distplot(df.Age) #shows histogram with kde ontop (y-axis for kde)

# %%
sns.jointplot(x='Age',y='Fare', data=df[df.Sex == 'male'])

# %%
ax = sns.distplot(df[df.Sex == 'female']['Age'], label='Females')
sns.distplot(df[df.Sex == 'male']['Age'], label='Males', ax=ax)
plt.legend(loc='best')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, x_vars=['Pclass', 'Age', 'Fare', 'SibSp'], y_vars=['Age'])

# %%
sns.heatmap(df.corr())
