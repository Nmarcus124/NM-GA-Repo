# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
drinks = pd.read_csv('/Users/natimarcus/Desktop/DAT-06-24/class material/Unit 2/data/drinks.csv')

# %%
print(drinks.columns)
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.rename(columns={'beer_servings':'beer','spirit_servings':'spirits','wine_servings':'wine'})
# Out:
#                   country  beer  spirits  wine  total_litres_of_pure_alcohol  \
# 0             Afghanistan     0        0     0                           0.0
# 1                 Albania    89      132    54                           4.9
# 2                 Algeria    25        0    14                           0.7
# 3                 Andorra   245      138   312                          12.4
# 4                  Angola   217       57    45                           5.9
# 5       Antigua & Barbuda   102      128    45                           4.9
# 6               Argentina   193       25   221                           8.3
# 7                 Armenia    21      179    11                           3.8
# 8               Australia   261       72   212                          10.4
# 9                 Austria   279       75   191                           9.7
# 10             Azerbaijan    21       46     5                           1.3
# ...

# %%
drinks.rename(columns={'beer_servings':'beer','spirit_servings':'spirits','wine_servings':'wine','total_litres_of_pure_alcohol':'liters'},inplace=True) #actually replaces

# %%
drinks.head()
# Out:
#        country  beer  spirits  wine  liters continent
# 0  Afghanistan     0        0     0     0.0        AS
# 1      Albania    89      132    54     4.9        EU
# 2      Algeria    25        0    14     0.7        AF
# 3      Andorra   245      138   312    12.4        EU
# 4       Angola   217       57    45     5.9        AF

# %%
drinks.drop(13)
drinks.iloc[13]
# Out:
# country      Bangladesh
# beer                  0
# spirits               0
# wine                  0
# liters                0
# continent            AS
# Name: 13, dtype: object

# %%
drinks.drop('liters',axis=1)
# Out:
#                   country  beer  spirits  wine continent
# 0             Afghanistan     0        0     0        AS
# 1                 Albania    89      132    54        EU
# 2                 Algeria    25        0    14        AF
# 3                 Andorra   245      138   312        EU
# 4                  Angola   217       57    45        AF
# 5       Antigua & Barbuda   102      128    45       NaN
# 6               Argentina   193       25   221        SA
# 7                 Armenia    21      179    11        EU
# 8               Australia   261       72   212        OC
# 9                 Austria   279       75   191        EU
# 10             Azerbaijan    21       46     5        EU
# 11                Bahamas   122      176    51       NaN
# 12                Bahrain    42       63     7        AS
# 13             Bangladesh     0        0     0        AS
# 14               Barbados   143      173    36       NaN
# ...

# %%
drinks.drop('liters',axis=1,inplace=True)

# %%
drinks.head()
# Out:
#        country  beer  spirits  wine continent
# 0  Afghanistan     0        0     0        AS
# 1      Albania    89      132    54        EU
# 2      Algeria    25        0    14        AF
# 3      Andorra   245      138   312        EU
# 4       Angola   217       57    45        AF

# %%
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
drinks.continent.value_counts(dropna=False) #shows null values too
# Out:
# AF     53
# EU     45
# AS     44
# NaN    23
# OC     16
# SA     12
# Name: continent, dtype: int64

# %%
drinks.continent.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14      True
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 163    False
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# 173    False
# 174     True
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184     True
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: continent, Length: 193, dtype: bool

# %%
drinks.continent.isnull().sum() #counts all nulls in column "continent"
# Out:
# 23

# %%
drinks.isnull().sum()
# Out:
# country       0
# beer          0
# spirits       0
# wine          0
# continent    23
# dtype: int64

# %%
drinks.continent.notnull().sum()
# Out:
# 170

# %%
drinks[drinks.continent.notnull()].head()
# Out:
#        country  beer  spirits  wine continent
# 0  Afghanistan     0        0     0        AS
# 1      Albania    89      132    54        EU
# 2      Algeria    25        0    14        AF
# 3      Andorra   245      138   312        EU
# 4       Angola   217       57    45        AF

# %%
print(drinks.isnull().sum())

drinks.isnull().sum().plot(kind='bar');
plt.title('Number of null values per column');
# Out:
# country       0
# beer          0
# spirits       0
# wine          0
# continent    23
# dtype: int64

# %%
drinks.dropna() #drops a row if it has a null values
# Out:
#                       country  beer  spirits  wine continent
# 0                 Afghanistan     0        0     0        AS
# 1                     Albania    89      132    54        EU
# 2                     Algeria    25        0    14        AF
# 3                     Andorra   245      138   312        EU
# 4                      Angola   217       57    45        AF
# 6                   Argentina   193       25   221        SA
# 7                     Armenia    21      179    11        EU
# 8                   Australia   261       72   212        OC
# 9                     Austria   279       75   191        EU
# 10                 Azerbaijan    21       46     5        EU
# 12                    Bahrain    42       63     7        AS
# 13                 Bangladesh     0        0     0        AS
# 15                    Belarus   142      373    42        EU
# 16                    Belgium   295       84   212        EU
# ...

# %%
drinks.dropna(how='all') #drops a row only if all values are null
# Out:
#                   country  beer  spirits  wine continent
# 0             Afghanistan     0        0     0        AS
# 1                 Albania    89      132    54        EU
# 2                 Algeria    25        0    14        AF
# 3                 Andorra   245      138   312        EU
# 4                  Angola   217       57    45        AF
# 5       Antigua & Barbuda   102      128    45       NaN
# 6               Argentina   193       25   221        SA
# 7                 Armenia    21      179    11        EU
# 8               Australia   261       72   212        OC
# 9                 Austria   279       75   191        EU
# 10             Azerbaijan    21       46     5        EU
# 11                Bahamas   122      176    51       NaN
# 12                Bahrain    42       63     7        AS
# 13             Bangladesh     0        0     0        AS
# 14               Barbados   143      173    36       NaN
# ...

# %%
drinks.continent.fillna(value='NA') #fills null value in continent column
# Out:
# 0      AS
# 1      EU
# 2      AF
# 3      EU
# 4      AF
# 5      NA
# 6      SA
# 7      EU
# 8      OC
# 9      EU
# 10     EU
# 11     NA
# 12     AS
# 13     AS
# 14     NA
# 15     EU
# 16     EU
# 17     NA
# 18     AF
# 19     AS
# 20     SA
# 21     EU
# 22     AF
# 23     SA
# 24     AS
# 25     EU
# 26     AF
# 27     AF
# 28     AF
# 29     AF
#        ..
# 163    SA
# 164    AF
# 165    EU
# 166    EU
# 167    AS
# 168    AS
# 169    AS
# 170    EU
# 171    AS
# 172    AF
# 173    OC
# 174    NA
# 175    AF
# 176    AS
# 177    AS
# 178    OC
# 179    AF
# 180    EU
# 181    AS
# 182    EU
# 183    AF
# 184    NA
# 185    SA
# 186    AS
# 187    OC
# 188    SA
# 189    AS
# 190    AS
# 191    AF
# 192    AF
# Name: continent, Length: 193, dtype: object

# %%
drinks.continent.fillna(value='NA',inplace=True)

# %%
drinks.continent.value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# NA    23
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
drinks.groupby('continent').beer.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# NA    145.434783
# OC     89.687500
# SA    175.083333
# Name: beer, dtype: float64

# %%
drinks.groupby('continent').mean()
# Out:
#                  beer     spirits        wine
# continent
# AF          61.471698   16.339623   16.264151
# AS          37.045455   60.840909    9.068182
# EU         193.777778  132.555556  142.222222
# NA         145.434783  165.739130   24.521739
# OC          89.687500   58.437500   35.625000
# SA         175.083333  114.750000   62.416667

# %%
drinks.groupby('continent').beer.describe()
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# NA          23.0  145.434783  79.621163   1.0   80.00  143.0  198.00  285.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0

# %%
drinks.groupby('continent').beer.agg(['count','mean','min','max'])
# Out:
#            count        mean  min  max
# continent
# AF            53   61.471698    0  376
# AS            44   37.045455    0  247
# EU            45  193.777778    0  361
# NA            23  145.434783    1  285
# OC            16   89.687500    0  306
# SA            12  175.083333   93  333

# %%
drinks.groupby('continent').beer.agg(['count','mean','min','max']).sort_values('mean')
# Out:
#            count        mean  min  max
# continent
# AS            44   37.045455    0  247
# AF            53   61.471698    0  376
# OC            16   89.687500    0  306
# NA            23  145.434783    1  285
# SA            12  175.083333   93  333
# EU            45  193.777778    0  361

# %%
drinks.groupby('continent').describe()
# Out:
#            beer                                                             \
#           count        mean        std   min     25%    50%     75%    max
# continent
# AF         53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS         44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU         45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# NA         23.0  145.434783  79.621163   1.0   80.00  143.0  198.00  285.0
# OC         16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA         12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0
#
#           spirits              ...                 wine              \
#             count        mean  ...     75%    max count        mean
# continent                      ...
# AF           53.0   16.339623  ...   19.00  152.0  53.0   16.264151
# AS           44.0   60.840909  ...   98.00  326.0  44.0    9.068182
# ...
