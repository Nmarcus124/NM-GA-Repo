# %%
def palindrome_check(product):
    if product[0] == product[5] and product[1] == product[4] and product[2] == product[3]:
        return 'Palindrome'
    else:
        return False

# %%
product = 103301

# %%
palindrome_check(str(product))
# Out:
# 'Palindrome'

# %%
three_digit_set = set(range(100,1000))

# %%
product_list = []
for x in three_digit_set:
    product = x * (x+1)
    product_list.append(product)

# %%
product_list_2 = []
for x in three_digit_set:
    product = (x+1) * x
    product_list_2.append(product)

# %%
product_list_2
# Out:
# [10100,
#  10302,
#  10506,
#  10712,
#  10920,
#  11130,
#  11342,
#  11556,
#  11772,
#  11990,
#  12210,
#  12432,
#  12656,
#  12882,
#  13110,
#  13340,
#  13572,
#  13806,
#  14042,
#  14280,
#  14520,
#  14762,
#  15006,
#  15252,
#  15500,
#  15750,
#  16002,
#  16256,
#  16512,
#  16770,
#  17030,
#  17292,
#  17556,
#  17822,
#  18090,
#  18360,
#  18632,
#  18906,
#  19182,
#  19460,
#  19740,
#  20022,
#  20306,
#  20592,
#  20880,
#  21170,
#  21462,
#  21756,
#  22052,
#  22350,
#  22650,
#  22952,
#  23256,
#  23562,
#  23870,
#  24180,
#  24492,
#  24806,
#  25122,
#  25440,
#  25760,
#  26082,
#  26406,
#  26732,
#  27060,
#  27390,
#  27722,
#  28056,
#  28392,
#  28730,
#  29070,
#  29412,
#  29756,
#  30102,
#  30450,
#  30800,
#  31152,
#  31506,
#  31862,
#  32220,
#  32580,
#  32942,
#  33306,
#  33672,
#  34040,
#  34410,
#  34782,
#  35156,
#  35532,
#  35910,
#  36290,
#  36672,
#  37056,
#  37442,
#  37830,
#  38220,
#  38612,
#  39006,
#  39402,
#  39800,
# ...

# %%
six_digit_product_list = []
for x in product_list:
    if x > 100000:
        six_digit_product_list.append(x)

# %%
palindrome_list = []
for x in six_digit_product_list:
    if palindrome_check(str(x)) == 'Palindrome':
        palindrome_list.append(x)

# %%
palindrome_list
# Out:
# [289982]

# %%
numbers = list(range(1,2000))

# %%
mods_list = []
def mod_calc(number):
    for x in numbers:
        mod = number%x
        mods_list.append(mod)

# %%
def zero_counter(mods_list):
    zero_count = 0
    for x in mods_list:
        if x == 0:
            zero_count += 1
    return zero_count

# %%
def is_prime(zero_counter):
    if zero_counter <= 2:
        return 'prime'
    else:
        return 'not prime'

# %%
number = 2

# %%
mod_calc(number)

# %%
mods_list
# Out:
# [0,
#  0,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
# ...

# %%
zero_counter(mods_list)
# Out:
# 2

# %%
is_prime(zero_counter(mods_list))
# Out:
# 'prime'

# %%
def string_count(word):
    a_c = 0
    b_c = 0
    c_c = 0
    d_c = 0
    e_c = 0
    f_c = 0
    g_c = 0
    h_c = 0
    i_c = 0
    j_c = 0
    k_c = 0
    l_c = 0
    m_c = 0
    n_c = 0
    o_c = 0
    p_c = 0
    q_c = 0
    r_c = 0
    s_c = 0
    t_c = 0
    u_c = 0
    v_c = 0
    w_c = 0
    x_c = 0 
    y_c = 0
    z_c = 0
    character_list = []
    for letter in word:
        if letter == 'a' or letter == 'A':
            a_c += 1
        elif letter == 'b' or letter == 'B':
            b_c += 1
        elif letter == 'c' or letter == 'C':
            c_c += 1
        elif letter == 'd' or letter == 'D':
            d_c += 1
        elif letter == 'e' or letter == 'E':
            e_c += 1
        elif letter == 'f' or letter == 'F':
            f_c += 1
        elif letter == 'g' or letter == 'G':
            g_c += 1
        elif letter == 'h' or letter == 'H':
            h_c += 1
        elif letter == 'i' or letter == 'I':
            i_c += 1
        elif letter == 'j' or letter == 'J':
            j_c += 1
        elif letter == 'k' or letter == 'K':
            k_c += 1
        elif letter == 'l' or letter == 'L':
            l_c += 1
        elif letter == 'm' or letter == 'M':
            m_c += 1
        elif letter == 'n' or letter == 'N':
            n_c += 1
        elif letter == 'o' or letter == 'O':
            o_c += 1
        elif letter == 'p' or letter == 'P':
            p_c += 1
        elif letter == 'q' or letter == 'Q':
            q_c += 1
        elif letter == 'r' or letter == 'R':
            r_c += 1
        elif letter == 's' or letter == 'S':
            s_c += 1
        elif letter == 't' or letter == 'T':
            t_c += 1
        elif letter == 'u' or letter == 'U':
            u_c += 1
        elif letter == 'v' or letter == 'V':
            v_c += 1
        elif letter == 'w' or letter == 'W':
            w_c += 1
        elif letter == 'x' or letter == 'X':
            x_c += 1
        elif letter == 'y' or letter == 'Y':
            y_c += 1
        elif letter == 'z' or letter == 'Z':
            z_c += 1
    character_list.append(a_c)
    character_list.append(b_c)
    character_list.append(c_c)
    character_list.append(d_c)
    character_list.append(e_c)
    character_list.append(f_c)
    character_list.append(g_c)
    character_list.append(h_c)
    character_list.append(i_c)
    character_list.append(j_c)
    character_list.append(k_c)
    character_list.append(l_c)
    character_list.append(m_c)
    character_list.append(n_c)
    character_list.append(o_c)
    character_list.append(p_c)
    character_list.append(q_c)
    character_list.append(r_c)
    character_list.append(s_c)
    character_list.append(t_c)
    character_list.append(u_c)
    character_list.append(v_c)
    character_list.append(w_c)
    character_list.append(x_c)
    character_list.append(y_c)
    character_list.append(z_c)
    condensed_list = []
    for x in character_list:
        if x > 0:
            condensed_list.append(x)
    return condensed_list

# %%
numbers = list(range(1,2000))

# %%
mods_list = []
def mod_calc(number):
    for x in numbers:
        mod = number%x
        mods_list.append(mod)

# %%
def zero_counter(mods_list):
    count_of_zeros = 0
    for x in mods_list:
        if x == 0:
            count_of_zeros += 1
    return count_of_zeros

# %%
def is_prime(count_of_zeros):
    if count_of_zeros <= 2:
        return 'prime'
    else:
        return 'not prime'

# %%
sum_of_primes = 0
for x in numbers:
    mod_calc(x)
    zero_counter(mods_list)
    is_prime(zero_counter(mods_list))
    if is_prime(zero_counter(mods_list)) == 'prime':
        sum_of_primes += x
