# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use("fivethirtyeight")

df = pd.read_csv('/Users/natimarcus/Desktop/DAT-06-24/class material/Unit 3/data/bikeshare.csv',index_col = 'datetime', parse_dates=True)

# %%
df.head()
# Out:
#                      season  holiday  workingday      weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00  Spring        0           0  Clear Skies  9.84  14.395
# 2011-01-01 01:00:00  Spring        0           0  Clear Skies  9.02  13.635
# 2011-01-01 02:00:00  Spring        0           0  Clear Skies  9.02  13.635
# 2011-01-01 03:00:00  Spring        0           0  Clear Skies  9.84  14.395
# 2011-01-01 04:00:00  Spring        0           0  Clear Skies  9.84  14.395
#
#                      humidity  windspeed  count
# datetime
# 2011-01-01 00:00:00        81        0.0     16
# 2011-01-01 01:00:00        80        0.0     40
# 2011-01-01 02:00:00        80        0.0     32
# 2011-01-01 03:00:00        75        0.0     13
# 2011-01-01 04:00:00        75        0.0      1

# %%
new_dict = {
    'Clear Skies': 4,
    'Partly Cloudy': 3,
    'Light Storms/Rain':2,
    'Heavy Storms/Rain':1
}

df.weather = df.weather.map(new_dict)

# %%
df.head()
# Out:
#                      season  holiday  workingday  weather  temp   atemp  \
# datetime
# 2011-01-01 00:00:00  Spring        0           0        4  9.84  14.395
# 2011-01-01 01:00:00  Spring        0           0        4  9.02  13.635
# 2011-01-01 02:00:00  Spring        0           0        4  9.02  13.635
# 2011-01-01 03:00:00  Spring        0           0        4  9.84  14.395
# 2011-01-01 04:00:00  Spring        0           0        4  9.84  14.395
#
#                      humidity  windspeed  count
# datetime
# 2011-01-01 00:00:00        81        0.0     16
# 2011-01-01 01:00:00        80        0.0     40
# 2011-01-01 02:00:00        80        0.0     32
# 2011-01-01 03:00:00        75        0.0     13
# 2011-01-01 04:00:00        75        0.0      1

# %%
pd.get_dummies(df.season, drop_first=True).head()
# Out:
#                      Spring  Summer  Winter
# datetime
# 2011-01-01 00:00:00       1       0       0
# 2011-01-01 01:00:00       1       0       0
# 2011-01-01 02:00:00       1       0       0
# 2011-01-01 03:00:00       1       0       0
# 2011-01-01 04:00:00       1       0       0

# %%
df = pd.get_dummies(df, drop_first = True)

# %%
df.head()
# Out:
#                      holiday  workingday  weather  temp   atemp  humidity  \
# datetime
# 2011-01-01 00:00:00        0           0        4  9.84  14.395        81
# 2011-01-01 01:00:00        0           0        4  9.02  13.635        80
# 2011-01-01 02:00:00        0           0        4  9.02  13.635        80
# 2011-01-01 03:00:00        0           0        4  9.84  14.395        75
# 2011-01-01 04:00:00        0           0        4  9.84  14.395        75
#
#                      windspeed  count  season_Spring  season_Summer  \
# datetime
# 2011-01-01 00:00:00        0.0     16              1              0
# 2011-01-01 01:00:00        0.0     40              1              0
# 2011-01-01 02:00:00        0.0     32              1              0
# 2011-01-01 03:00:00        0.0     13              1              0
# 2011-01-01 04:00:00        0.0      1              1              0
#
#                      season_Winter
# datetime
# 2011-01-01 00:00:00              0
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
x = df.loc[:, df.columns != 'count']
y = df['count']

num_cols = x.select_dtypes(include=np.number).columns.tolist()
x[num_cols] = (x[num_cols] - x[num_cols].mean()) / x[num_cols].std()

# %%
lr = LinearRegression()
lr.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lr.score(x,y)
# Out:
# 0.2752503232099429

# %%
coeffs = pd.DataFrame({
    'Variable':x_std.columns,
    'Weight':lr.coef_
}).sort_values(by='Weight', ascending=False)
coeffs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-98e0b31d485f> in <module>()
#       1 coeffs = pd.DataFrame({
# ----> 2     'Variable':x_std.columns,
#       3     'Weight':lr.coef_
#       4 }).sort_values(by='Weight', ascending=False)
#       5 coeffs
#
# NameError: name 'x_std' is not defined

# %%
import statsmodels.api as sm

mod = sm.OLS(y, x)
results = mod.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  count   R-squared (uncentered):                   0.130
# Model:                            OLS   Adj. R-squared (uncentered):              0.129
# Method:                 Least Squares   F-statistic:                              162.4
# Date:                Wed, 31 Jul 2019   Prob (F-statistic):                   2.16e-319
# Time:                        19:46:57   Log-Likelihood:                         -75374.
# No. Observations:               10886   AIC:                                  1.508e+05
# Df Residuals:                   10876   BIC:                                  1.508e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
prices = pd.read_csv('/Users/natimarcus/Desktop/DAT-06-24/class material/Unit 3/data/sac_re_cat.csv', index_col='sale_date', parse_dates=False)

# %%
prices.head()
# Out:
#                                         street        city    zip state  beds  \
# sale_date
# Wed May 21 00:00:00 EDT 2008      3526 HIGH ST  SACRAMENTO  95838    CA     2
# Wed May 21 00:00:00 EDT 2008       51 OMAHA CT  SACRAMENTO  95823    CA     3
# Wed May 21 00:00:00 EDT 2008    2796 BRANCH ST  SACRAMENTO  95815    CA     2
# Wed May 21 00:00:00 EDT 2008  2805 JANETTE WAY  SACRAMENTO  95815    CA     2
# Wed May 21 00:00:00 EDT 2008   6001 MCMAHON DR  SACRAMENTO  95824    CA     2
#
#                               baths  sq__ft         type  price
# sale_date
# Wed May 21 00:00:00 EDT 2008      1     836  Residential  59222
# Wed May 21 00:00:00 EDT 2008      1    1167  Residential  68212
# Wed May 21 00:00:00 EDT 2008      1     796  Residential  68880
# Wed May 21 00:00:00 EDT 2008      1     852  Residential  69307
# Wed May 21 00:00:00 EDT 2008      1     797  Residential  81900

# %%
prices.zip = prices.zip.astype('category')

# %%
prices.groupby('zip').zip.count()
# Out:
# zip
# 95603     5
# 95608    20
# 95610     7
# 95614     1
# 95619     1
# 95621    28
# 95623     2
# 95624    34
# 95626     4
# 95628     9
# 95630    17
# 95631     1
# 95632    21
# 95633     1
# 95635     1
# 95648    72
# 95650     2
# 95655     1
# 95660    21
# 95661     8
# 95662    11
# 95663     1
# 95667    10
# 95670    21
# 95673    13
# 95677     6
# 95678    20
# 95682    10
# 95683     4
# 95690     1
#          ..
# 95758    44
# 95762    23
# 95765    11
# 95811     2
# 95814     3
# 95815    18
# 95816     4
# 95817     7
# 95818     7
# 95819     4
# 95820    23
# 95821     6
# 95822    24
# 95823    61
# 95824    12
# 95825    13
# 95826    18
# 95827     9
# 95828    45
# 95829    11
# 95831    10
# 95832    12
# 95833    20
# 95834    22
# 95835    37
# 95838    37
# 95841     7
# 95842    22
# 95843    33
# 95864     5
# Name: zip, Length: 68, dtype: int64

# %%
transformed = prices.groupby('zip').zip.transform('count')

# %%
prices['zip'] = np.where(transformed < 25, 'Other', prices['zip'])

# %%
prices['zip'].value_counts()
# Out:
# Other    558
# 95648     72
# 95823     61
# 95828     45
# 95758     44
# 95835     37
# 95838     37
# 95757     36
# 95624     34
# 95843     33
# 95621     28
# Name: zip, dtype: int64

# %%
x = prices[['beds', 'baths', 'sq__ft']]
y = prices['price']

x = (x - x.mean()) / x.std()

# %%
lr = LinearRegression()
lr.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lr.score(x,y)
# Out:
# 0.18203162472419276

# %%
x = prices[['zip','beds', 'baths', 'sq__ft']]
y = prices['price']

x = (x - x.mean()) / x.std()

lr = LinearRegression()
lr.fit(x, y)

lr.score(x,y)

# %%
x = prices[['type','beds', 'baths', 'sq__ft']]
y = prices['price']

x = (x - x.mean()) / x.std()

lr = LinearRegression()
lr.fit(x, y)

lr.score(x,y)

# %%
prices['prediction'] = lr.predict(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-faa68af3ac42> in <module>()
# ----> 1 prices['prediction'] = lr.predict(x)
#
# /anaconda3/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# /anaconda3/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in _decision_function(self, X)
#     194         check_is_fitted(self, "coef_")
#     195
# --> 196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     197         return safe_sparse_dot(X, self.coef_.T,
#     198                                dense_output=True) + self.intercept_
#
# ...

# %%
prices.head()
# Out:
#                                         street        city    zip state  beds  \
# sale_date
# Wed May 21 00:00:00 EDT 2008      3526 HIGH ST  SACRAMENTO  95838    CA     2
# Wed May 21 00:00:00 EDT 2008       51 OMAHA CT  SACRAMENTO  95823    CA     3
# Wed May 21 00:00:00 EDT 2008    2796 BRANCH ST  SACRAMENTO  Other    CA     2
# Wed May 21 00:00:00 EDT 2008  2805 JANETTE WAY  SACRAMENTO  Other    CA     2
# Wed May 21 00:00:00 EDT 2008   6001 MCMAHON DR  SACRAMENTO  Other    CA     2
#
#                               baths  sq__ft         type  price
# sale_date
# Wed May 21 00:00:00 EDT 2008      1     836  Residential  59222
# Wed May 21 00:00:00 EDT 2008      1    1167  Residential  68212
# Wed May 21 00:00:00 EDT 2008      1     796  Residential  68880
# Wed May 21 00:00:00 EDT 2008      1     852  Residential  69307
# Wed May 21 00:00:00 EDT 2008      1     797  Residential  81900

# %%
mae = np.mean(np.abs(prices['price'] - prices['prediction']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-741d546cc0dd> in <module>()
# ----> 1 np.mean(np.abs(prices['price'] - prices['prediction']))
#
# /anaconda3/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /anaconda3/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
# ...

# %%
mse = np.mean((prices['price'] - prices['prediction'])**2)

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(df['count'], df['prediction']))
print('MAE:', metrics.mean_squared_error(df['count'], df['prediction']))
